# %%
# Importar las bibliotecas necesarias
import pandas as pd
import matplotlib.pyplot as plt

# %%
avocado_df = pd.read_csv('../dataset/avocado_df.csv')

# %% [markdown]
# **Informe del Análisis Exploratorio de Datos (EDA)**: Un informe en formato markdown que resuma los hallazgos clave del análisis exploratorio. Incluir visualizaciones de los patrones encontrados y explicaciones claras sobre las conclusiones obtenidas.

# %% [markdown]
# **Base de datos de venta de aguacates (2021 - 2024) - Hass Avocado Board**

# %%
avocado_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24536 entries, 0 to 24535
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Geography                  24536 non-null  object
#  1   Timeframe                  24536 non-null  object
#  2   Current Year Week Ending   24536 non-null  object
#  3   Type                       24536 non-null  object
#  4   ASP Current Year           24536 non-null  float64
#  5   Total Bulk and Bags Units  24536 non-null  float64
#  6   4046 Units                 24536 non-null  float64
#  7   4225 Units                 24536 non-null  float64
#  8   4770 Units                 24536 non-null  float64
#  9   TotalBagged Units          24536 non-null  float64
#  10  SmlBagged Units            0 non-null      float64
#  11  LrgBagged Units            0 non-null      float64
#  12  X-LrgBagged Units          0 non-null      float64
# ...

# %%
avocado_df.describe()
# Out:
#        ASP Current Year  Total Bulk and Bags Units    4046 Units  \
# count      24536.000000               2.453600e+04  2.453600e+04
# mean           1.340299               1.018375e+06  4.666806e+05
# std            0.334727               4.063736e+06  1.968989e+06
# min            0.607247               2.676100e+03  0.000000e+00
# 25%            1.085036               2.986215e+04  1.100915e+03
# 50%            1.298635               1.631951e+05  4.483338e+04
# 75%            1.539138               5.349558e+05  2.341009e+05
# max            3.179988               6.034646e+07  3.113597e+07
#
#          4225 Units    4770 Units  TotalBagged Units  SmlBagged Units  \
# count  2.453600e+04  2.453600e+04       2.453600e+04              0.0
# mean   2.118439e+05  2.820130e+04       3.116492e+05              NaN
# std    9.026263e+05  1.421914e+05       1.149713e+06              NaN
# min    0.000000e+00  0.000000e+00       1.251590e+03              NaN
# ...

# %%
avocado_df.count()
# Out:
# Geography                    24536
# Timeframe                    24536
# Current Year Week Ending     24536
# Type                         24536
# ASP Current Year             24536
# Total Bulk and Bags Units    24536
# 4046 Units                   24536
# 4225 Units                   24536
# 4770 Units                   24536
# TotalBagged Units            24536
# SmlBagged Units                  0
# LrgBagged Units                  0
# X-LrgBagged Units                0
# dtype: int64

# %%
unique_values = avocado_df.nunique()
unique_values
# Out:
# Geography                       59
# Timeframe                        1
# Current Year Week Ending       208
# Type                             2
# ASP Current Year             23586
# Total Bulk and Bags Units    23579
# 4046 Units                   23348
# 4225 Units                   23160
# 4770 Units                   13313
# TotalBagged Units            23571
# SmlBagged Units                  0
# LrgBagged Units                  0
# X-LrgBagged Units                0
# dtype: int64

# %%
print(avocado_df['Geography'].unique())
# Out:
# ['Albany' 'Atlanta' 'Baltimore/Washington' 'Birmingham/Montgomery' 'Boise'
#  'Boston' 'Buffalo/Rochester' 'Charlotte' 'Chicago' 'Cincinnati/Dayton'
#  'Columbus' 'Dallas/Ft. Worth' 'Denver' 'Detroit' 'Grand Rapids'
#  'Harrisburg/Scranton' 'Hartford/Springfield' 'Houston' 'Indianapolis'
#  'Jacksonville' 'Las Vegas' 'Los Angeles' 'Louisville'
#  'Miami/Ft. Lauderdale' 'Nashville' 'Northern New England'
#  'New Orleans/Mobile' 'New York' 'Orlando' 'Peoria/Springfield'
#  'Philadelphia' 'Phoenix/Tucson' 'Pittsburgh' 'Portland' 'Providence'
#  'Raleigh/Greensboro' 'Richmond/Norfolk' 'Roanoke' 'Sacramento'
#  'San Diego' 'San Francisco' 'Seattle' 'South Carolina' 'Spokane'
#  'St. Louis' 'Syracuse' 'Tampa' 'Toledo' 'West Tex/New Mexico' 'Wichita'
#  'California' 'Great Lakes' 'Midsouth' 'Northeast' 'Plains'
#  'South Central' 'Southeast' 'West' 'Total U.S.']

# %%
avocado_df.head()
# Out:
#                Geography Timeframe Current Year Week Ending          Type  \
# 0                 Albany    Weekly               2021-01-11  Conventional
# 1                Atlanta    Weekly               2021-01-11  Conventional
# 2   Baltimore/Washington    Weekly               2021-01-11  Conventional
# 3  Birmingham/Montgomery    Weekly               2021-01-11  Conventional
# 4                  Boise    Weekly               2021-01-11  Conventional
#
#    ASP Current Year  Total Bulk and Bags Units  4046 Units  4225 Units  \
# 0          1.194755                  150112.17    17074.48   100955.99
# 1          0.812573                  892386.79   542057.87   146831.96
# 2          1.073194                 1203423.07   402341.66   365970.12
# 3          0.757310                  402306.65   263020.12    17855.75
# 4          1.033496                  138962.53    57581.95    34044.86
#
#    4770 Units  TotalBagged Units  SmlBagged Units  LrgBagged Units  \
# ...

# %%
cities = ['Albany', 'Atlanta', 'Boise', 'Boston', 'Charlotte', 'Chicago', 'Columbus', 
          'Denver', 'Detroit', 'Grand Rapids', 'Houston', 'Indianapolis', 'Jacksonville', 
          'Las Vegas', 'Los Angeles', 'Louisville', 'Nashville', 'New York', 'Orlando', 
          'Philadelphia', 'Pittsburgh', 'Providence', 'Portland', 'Roanoke', 'Sacramento', 
          'San Diego', 'San Francisco', 'Seattle', 'Spokane', 'St. Louis', 'Syracuse', 
          'Tampa', 'Toledo', 'Wichita']

regions = ['Baltimore/Washington', 'Birmingham/Montgomery', 'Buffalo/Rochester', 
           'Cincinnati/Dayton', 'Dallas/Ft. Worth', 'Harrisburg/Scranton', 
           'Hartford/Springfield', 'Miami/Ft. Lauderdale', 'New Orleans/Mobile', 
           'Northern New England', 'Peoria/Springfield', 'Phoenix/Tucson', 
           'Raleigh/Greensboro', 'Richmond/Norfolk', 'South Carolina', 'West Tex/New Mexico']

greaterregions = ['California', 'Great Lakes', 'Midsouth', 'Northeast', 'Plains', 
                  'South Central', 'Southeast', 'West']

filtered_df_greaterregions = avocado_df[avocado_df['Geography'].isin(greaterregions)]

filtered_df_greaterregions.head()
# Out:
#       Geography Timeframe Current Year Week Ending          Type  \
# 50   California    Weekly               2021-01-11  Conventional
# 51  Great Lakes    Weekly               2021-01-11  Conventional
# 52     Midsouth    Weekly               2021-01-11  Conventional
# 53    Northeast    Weekly               2021-01-11  Conventional
# 54       Plains    Weekly               2021-01-11  Conventional
#
#     ASP Current Year  Total Bulk and Bags Units  4046 Units  4225 Units  \
# 50          1.092303                 7305333.58  2845001.28  2152753.34
# 51          0.909006                 5245629.02  2154802.80  1508395.12
# 52          0.904031                 4935644.59  2239861.89  1133848.51
# 53          1.074509                 6586438.02  1046371.60  3486564.63
# 54          0.853520                 2605939.78  1279482.18   560207.22
#
#     4770 Units  TotalBagged Units  SmlBagged Units  LrgBagged Units  \
# 50   959794.53         1347784.44              NaN              NaN
# ...

# %% [markdown]
# **Análisis Bivariado**

# %%
# Agrupar por "Geography" y calcular la media de "Total Bulk and Bags Units"
geography_mean = filtered_df_greaterregions.groupby('Geography')['Total Bulk and Bags Units'].mean()

# Graficar los datos
plt.figure(figsize=(12, 8))
geography_mean.plot(kind='bar')
plt.xlabel('Grandes regiones')
plt.ylabel('Media del total de unidades a granel y en sacos (lbs)')
plt.title('Media del total de unidades a granel y en sacos (lbs) por Grandes regiones')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# La gráfica de barras muestra la media del total de unidades a granel y en sacos (en libras) en diferentes grandes regiones. Las principales observaciones son:
# 1. La región Oeste tiene la media más alta, superando los 3.5 millones de libras, seguida de cerca por California y Sureste.
# 2.	La región de Plains presenta la media más baja, con poco más de 1 millón de libras, muy por debajo del resto de las regiones.
# 3.	Regiones como Noreste, Grandes Lagos y Midsouth muestran medias moderadas, cercanas a los 2.5 millones de libras.
# 4.	La región Centro Sur también destaca con un total relativamente alto, cercano a los 3 millones de libras.
#
# Esto sugiere que las ventas de aguacates (medidas en unidades a granel y en sacos) son particularmente fuertes en las regiones Oeste, Sureste y California, mientras que la región de Plains muestra un rezago significativo.

# %%
# Convertir la columna 'Current Year Week Ending' a tipo datetime
filtered_df_greaterregions['Current Year Week Ending'] = pd.to_datetime(filtered_df_greaterregions['Current Year Week Ending'])

# Crear una nueva columna 'Quarter' que contenga el trimestre del año
filtered_df_greaterregions['Quarter'] = filtered_df_greaterregions['Current Year Week Ending'].dt.to_period('Q')

# Crear una nueva columna 'Month' que contenga el mes del año
filtered_df_greaterregions['Month'] = filtered_df_greaterregions['Current Year Week Ending'].dt.to_period('M')

# Calcular la media de 'Total Bulk and Bags Units' agrupada por trimestre
quarterly_mean = filtered_df_greaterregions.groupby('Quarter')['Total Bulk and Bags Units'].mean()

# Crear una figura de tamaño 12x8 para la gráfica
plt.figure(figsize=(12, 8))
quarterly_mean.plot(kind='line', marker='o')
plt.xlabel('Trimestre')
plt.ylabel('Media del total de unidades a granel y en sacos (lbs)')
plt.title('Grandes regiones: Media del total de unidades a granel y en sacos (lbs) por Trimestre')

plt.show()
# Out:
# /var/folders/7z/00rgwf311yn2q_dbm8dwq25m0000gn/T/ipykernel_5386/2939270185.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_greaterregions['Current Year Week Ending'] = pd.to_datetime(filtered_df_greaterregions['Current Year Week Ending'])
# /var/folders/7z/00rgwf311yn2q_dbm8dwq25m0000gn/T/ipykernel_5386/2939270185.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# La gráfica muestra la evolución trimestral de la media del total de unidades a granel y en sacos (en libras). Las principales observaciones son:
# 1.	2021 inicia con valores altos cercanos a los 3.2 millones de libras, pero presenta una caída constante a lo largo del año.
# 2.	A principios de 2022, se observa un mínimo alrededor de 2.4 millones de libras, seguido de un repunte temporal, aunque termina nuevamente en valores bajos.
# 3.	En 2023, hay un notable aumento significativo, alcanzando niveles por encima de los 3 millones de libras, seguido de una caída en los trimestres posteriores.
# 4.	El 2024 muestra un comportamiento volátil, con un máximo superior a los 3.2 millones de libras, seguido de una caída y un ligero repunte al final.
#
# En general, la evolución por trimestre revela una tendencia cíclica con fuertes fluctuaciones, donde se alternan períodos de altas y bajas que sugieren estacionalidad o factores externos que afectan las ventas de unidades a granel y en sacos.

# %%
# Ordenar el DataFrame por "Current Year Week Ending", "Geography" y "Type"
filtered_df_greaterregions = filtered_df_greaterregions.sort_values(by=['Current Year Week Ending', 'Geography', 'Type'])

# Filtrar el DataFrame para incluir solo las filas donde Geography es "California" y Type es "Organic"
california_organic_df = filtered_df_greaterregions[(filtered_df_greaterregions['Geography'] == 'California') & (filtered_df_greaterregions['Type'] == 'Organic')]
# Filtrar el DataFrame para incluir solo las filas donde Geography es "California" y Type es "Conventional"
california_conventional_df = filtered_df_greaterregions[(filtered_df_greaterregions['Geography'] == 'California') & (filtered_df_greaterregions['Type'] == 'Conventional')]

# Calcular el cambio porcentual para Total Bulk and Bags Units y ASP Current Year
california_organic_df['Pct_Change_Units'] = california_organic_df['Total Bulk and Bags Units'].pct_change()
california_organic_df['Pct_Change_Price'] = california_organic_df['ASP Current Year'].pct_change()

california_conventional_df['Pct_Change_Units'] = california_conventional_df['Total Bulk and Bags Units'].pct_change()
california_conventional_df['Pct_Change_Price'] = california_conventional_df['ASP Current Year'].pct_change()

# Calcular la elasticidad precio de la demanda
california_organic_df['Elasticity'] = california_organic_df['Pct_Change_Units'] / california_organic_df['Pct_Change_Price']
california_conventional_df['Elasticity'] = california_conventional_df['Pct_Change_Units'] / california_conventional_df['Pct_Change_Price']

# Rellenar los valores nulos en Elasticity con "0", excepto para los registros con Current Year Week Ending igual a 2021-01-11

# Para california_organic_df
california_organic_df.loc[(california_organic_df['Current Year Week Ending'] != '2021-01-11') & (california_organic_df['Elasticity'].isnull()), 'Elasticity'] = 0

# Para california_conventional_df
california_conventional_df.loc[(california_conventional_df['Current Year Week Ending'] != '2021-01-11') & (california_conventional_df['Elasticity'].isnull()), 'Elasticity'] = 0

# Unir california_organic_df y california_conventional_df
california_df = pd.concat([california_organic_df, california_conventional_df])

# Guardar el DataFrame unido en un nuevo archivo CSV
california_df.to_csv('../dataset/california_df.csv', index=False)
# Out:
# /var/folders/7z/00rgwf311yn2q_dbm8dwq25m0000gn/T/ipykernel_5386/3335212704.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   california_organic_df['Pct_Change_Units'] = california_organic_df['Total Bulk and Bags Units'].pct_change()
# /var/folders/7z/00rgwf311yn2q_dbm8dwq25m0000gn/T/ipykernel_5386/3335212704.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   california_organic_df['Pct_Change_Price'] = california_organic_df['ASP Current Year'].pct_change()
# ...

# %%
california_df.head()
# Out:
#       Geography Timeframe Current Year Week Ending     Type  ASP Current Year  \
# 109  California    Weekly               2021-01-11  Organic          1.740612
# 227  California    Weekly               2021-01-17  Organic          1.745864
# 345  California    Weekly               2021-01-24  Organic          1.701653
# 463  California    Weekly               2021-01-31  Organic          1.585137
# 581  California    Weekly               2021-02-07  Organic          1.682935
#
#      Total Bulk and Bags Units  4046 Units  4225 Units  4770 Units  \
# 109                  376178.67   123236.27    57994.25       34.38
# 227                  394732.15   123138.69    68676.63        8.44
# 345                  406028.76   130153.90    66508.94        0.00
# 463                  389566.49   116970.90    66120.51       11.77
# 581                  390947.22   116341.45    70391.87       15.22
#
#      TotalBagged Units  SmlBagged Units  LrgBagged Units  X-LrgBagged Units  \
# ...

# %% [markdown]
# **Base de datos de ventas de aguacates y proveedor en California (2022-2024)**

# %%
# Agrupar los datos por mes y calcular la media de 'Total Bulk and Bags Units' y 'ASP Current Year' para orgánico y convencional
month_mean_california_organic = california_organic_df.groupby('Month')[['Total Bulk and Bags Units', 'ASP Current Year']].mean()
month_mean_california_conventional = california_conventional_df.groupby('Month')[['Total Bulk and Bags Units', 'ASP Current Year']].mean()

# Filtrar los datos para el año 2022
month_mean_california_organic_2022 = month_mean_california_organic[month_mean_california_organic.index.year == 2022]
month_mean_california_conventional_2022 = month_mean_california_conventional[month_mean_california_conventional.index.year == 2022]

# Crear una figura y un eje para la gráfica
fig, ax1 = plt.subplots(figsize=(12, 8))

# Graficar los datos de orgánico
ax1.plot(month_mean_california_organic_2022.index.to_timestamp(), month_mean_california_organic_2022['Total Bulk and Bags Units'], marker='o', label='Orgánico', color='g')
ax1.set_xlabel('Mes')
ax1.set_ylabel('Media del total de unidades a granel y en sacos (lb) vendidos - Orgánico', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Crear un segundo eje y para convencional
ax2 = ax1.twinx()
ax2.plot(month_mean_california_conventional_2022.index.to_timestamp(), month_mean_california_conventional_2022['Total Bulk and Bags Units'], marker='o', label='Convencional', color='#800000')
ax2.set_ylabel('Media del total de unidades a granel y en sacos (lb) vendidos - Convencional', color='#800000')
ax2.tick_params(axis='y', labelcolor='#800000')

# Configurar el eje x para mostrar cada mes
ax1.set_xticks(month_mean_california_organic_2022.index.to_timestamp())
ax1.set_xticklabels(month_mean_california_organic_2022.index.strftime('%b'), rotation=45)

# Añadir la leyenda
fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

# Título de la gráfica
plt.title('Grandes regiones: Media del total de unidades a granel y en sacos (lbs) vendidos por Mes en California (2022)')
fig.tight_layout()

plt.show()

# %% [markdown]
# La gráfica muestra la media del total de unidades a granel y en sacos (en libras) vendidas por mes en California durante el 2022, diferenciando entre aguacates orgánicos y convencionales. Las observaciones clave son las siguientes:
# 1. Tendencia de Orgánico (línea verde):
#     - Al inicio del año (enero y febrero), las ventas de aguacates orgánicos se mantienen altas, cerca de las 380,000 libras.
# 	- A partir de marzo, las ventas presentan una tendencia a la baja con fluctuaciones, alcanzando su mínimo en agosto con aproximadamente 300,000 libras.
# 	- En septiembre, hay un repunte significativo, pero cae nuevamente en octubre y noviembre, con una ligera recuperación en diciembre.
# 2.	Tendencia de Convencional (línea marrón):
# 	- Las ventas de aguacates convencionales comienzan en niveles altos en enero y febrero (alrededor de 6.6 millones de libras).
# 	- En marzo, se observa una fuerte caída, manteniéndose relativamente estables con pequeñas variaciones durante el resto del año.
# 	- El mes con mayor recuperación es septiembre, pero la tendencia general es descendente hacia finales del año.
# 3.	Comparación entre Orgánico y Convencional:
# 	- Los aguacates convencionales mantienen volúmenes de ventas significativamente superiores a los orgánicos a lo largo del año.
# 	- Sin embargo, las ventas de orgánicos muestran mayor volatilidad, con picos y caídas más marcados.
#
# En resumen, las ventas de aguacates convencionales son más constantes y dominan en volumen total, mientras que las ventas de aguacates orgánicos son más fluctuantes y presentan periodos de recuperación y caídas abruptas.

# %%
# Filtrar los datos para el año 2023
month_mean_california_organic_2023 = month_mean_california_organic[month_mean_california_organic.index.year == 2023]
month_mean_california_conventional_2023 = month_mean_california_conventional[month_mean_california_conventional.index.year == 2023]

# Crear una figura y un eje para la gráfica
fig, ax1 = plt.subplots(figsize=(12, 8))

# Graficar los datos de orgánico
ax1.plot(month_mean_california_organic_2023.index.to_timestamp(), month_mean_california_organic_2023['Total Bulk and Bags Units'], marker='o', label='Orgánico', color='g')
ax1.set_xlabel('Mes')
ax1.set_ylabel('Media del total de unidades a granel y en sacos (lb) vendidos - Orgánico', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Crear un segundo eje y para convencional
ax2 = ax1.twinx()
ax2.plot(month_mean_california_conventional_2023.index.to_timestamp(), month_mean_california_conventional_2023['Total Bulk and Bags Units'], marker='o', label='Convencional', color='#800000')
ax2.set_ylabel('Media del total de unidades a granel y en sacos (lbs) vendidos - Convencional', color='#800000')
ax2.tick_params(axis='y', labelcolor='#800000')

# Configurar el eje x para mostrar cada mes
ax1.set_xticks(month_mean_california_organic_2023.index.to_timestamp())
ax1.set_xticklabels(month_mean_california_organic_2023.index.strftime('%b'), rotation=45)

# Añadir la leyenda
fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

# Título de la gráfica
plt.title('Grandes regiones: Media del total de unidades a granel y en sacos (lbs) vendidos por Mes en California (2023)')
fig.tight_layout()
plt.show()

# %% [markdown]
# La gráfica muestra la media del total de unidades a granel y en sacos (en libras) vendidas por mes en California durante el 2023, diferenciando entre aguacates orgánicos (verde) y convencionales (marrón). Las observaciones clave son:
#
# Aguacates orgánicos:
# 1. Las ventas comienzan con un pico alto en enero cercano a las 440,000 libras, pero caen bruscamente en febrero.
# 2.	Durante el primer semestre, las ventas muestran fluctuaciones moderadas, alcanzando un máximo en abril y un mínimo en junio.
# 3.	En el segundo semestre, se observa una tendencia descendente constante, alcanzando su punto más bajo en noviembre (alrededor de 300,000 libras), con una ligera recuperación en diciembre.
#
# Aguacates convencionales:
# 1.	Las ventas son significativamente más altas que las de orgánicos, iniciando en enero con aproximadamente 6 millones de libras.
# 2.	El primer semestre presenta un incremento sostenido, con un pico en abril, seguido de una caída constante hasta junio.
# 3.	En la segunda mitad del año, las ventas permanecen relativamente estables alrededor de los 5.8 a 6 millones de libras, alcanzando su mínimo en noviembre. Al igual que los orgánicos, hay una recuperación en diciembre.
#
# Comparación:
# - Los aguacates convencionales mantienen niveles de ventas mucho más altos que los orgánicos a lo largo de todo el año.
# - Ambas categorías muestran una tendencia descendente hacia finales de año, con noviembre como el mes más bajo para ambos tipos.
# - Las ventas de orgánicos son más volátiles, mientras que las de convencionales son más consistentes.
#
# En conclusión, aunque los aguacates convencionales dominan en volumen total, ambos tipos experimentan comportamientos similares con caídas notables en el último trimestre del año.

# %%
# Filtrar los datos para el año 2024
month_mean_california_organic_2024 = month_mean_california_organic[month_mean_california_organic.index.year == 2024]
month_mean_california_conventional_2024 = month_mean_california_conventional[month_mean_california_conventional.index.year == 2024]

# Crear una figura y un eje para la gráfica
fig, ax1 = plt.subplots(figsize=(12, 8))

# Graficar los datos de orgánico
ax1.plot(month_mean_california_organic_2024.index.to_timestamp(), month_mean_california_organic_2024['Total Bulk and Bags Units'], marker='o', label='Orgánico', color='g')
ax1.set_xlabel('Mes')
ax1.set_ylabel('Media del total de unidades a granel y en sacos (lb) vendidos - Orgánico', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Crear un segundo eje y para convencional
ax2 = ax1.twinx()
ax2.plot(month_mean_california_conventional_2024.index.to_timestamp(), month_mean_california_conventional_2024['Total Bulk and Bags Units'], marker='o', label='Convencional', color='#800000')
ax2.set_ylabel('Media del total de unidades a granel y en sacos (lb) vendidos - Convencional', color='#800000')
ax2.tick_params(axis='y', labelcolor='#800000')

# Configurar el eje x para mostrar cada mes
ax1.set_xticks(month_mean_california_organic_2024.index.to_timestamp())
ax1.set_xticklabels(month_mean_california_organic_2024.index.strftime('%b'), rotation=45)

# Añadir la leyenda
fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

# Título de la gráfica
plt.title('Grandes regiones: Media del total de unidades a granel y en sacos (lbs) vendidos por Mes en California (2024)')
fig.tight_layout()
plt.show()

# %% [markdown]
# La gráfica muestra la media del total de unidades a granel y en sacos (en libras) vendidas por mes en California durante el 2024, diferenciando entre aguacates orgánicos (línea verde) y convencionales (línea marrón). Las principales observaciones son:
#
# Aguacates orgánicos:
# 1.	Las ventas inician en enero con valores cercanos a las 340,000 libras y presentan una caída ligera en febrero.
# 2.	A partir de marzo, se observa una tendencia al alza, alcanzando el máximo en junio con aproximadamente 370,000 libras.
# 3.	A partir de julio, las ventas comienzan a descender de forma continua, alcanzando su mínimo en noviembre y diciembre con valores cercanos a 300,000 libras.
#
# Aguacates convencionales:
# 1.	Las ventas comienzan con 340,000 libras en enero y tienen un aumento significativo en febrero, alcanzando las 360,000 libras.
# 2.	Entre marzo y julio, las ventas mantienen un comportamiento fluctuante, con un pico máximo en julio, superando los 7 millones de libras.
# 3.	A partir de agosto, las ventas de aguacates convencionales muestran una caída constante, llegando a su mínimo en noviembre y diciembre con aproximadamente 5.8 millones de libras.
#
# Comparación:
# - Los aguacates convencionales mantienen volúmenes considerablemente superiores a los orgánicos a lo largo del año.
# - Ambas categorías muestran comportamientos similares, con un aumento en la primera mitad del año y una tendencia descendente constante en la segunda mitad, especialmente hacia noviembre y diciembre.
# - La brecha entre los dos tipos es más marcada en julio, cuando los convencionales alcanzan su punto máximo.
#
# En conclusión, las ventas de aguacates en 2024 siguen un patrón cíclico, con una fuerte caída en los últimos meses del año. Aunque las ventas de aguacates convencionales dominan en volumen, las fluctuaciones son evidentes en ambos tipos.

# %%
# Calcular la media del precio medio de venta año en curso agrupada por trimestre
quarterly_mean = filtered_df_greaterregions.groupby('Quarter')['ASP Current Year'].mean()

# Crear una figura de tamaño 10x6 para la gráfica
plt.figure(figsize=(12, 8))

# Graficar los datos como una línea con marcadores
quarterly_mean.plot(kind='line', marker='o')

# Etiqueta del eje x
plt.xlabel('Trimestre')

# Etiqueta del eje y
plt.ylabel('Precio medio de venta año en curso')

# Título de la gráfica
plt.title('Grandes regiones: Media del precio medio de venta año en curso por Trimestre')

plt.show()

# %% [markdown]
# La gráfica muestra la media del precio medio de venta por trimestre a lo largo de los años 2021 a 2024 en grandes regiones. Las principales observaciones son las siguientes:
# 1. Tendencia ascendente en 2021 y 2022:
# 	- El precio medio de venta comienza en niveles bajos en 2021 (alrededor de 1.1) y experimenta un incremento constante hasta alcanzar su pico máximo en el primer trimestre de 2022, con un valor superior a 1.6.
# 	- Este periodo representa el máximo precio medio en toda la serie temporal.
# 2. Caída pronunciada en 2022 y 2023:
# 	- Después del pico en el primer trimestre de 2022, se observa una caída drástica a lo largo del resto del año, continuando en 2023, donde los precios alcanzan su punto más bajo en el primer trimestre, cercano a 1.1.
# 	- Este periodo muestra la mayor disminución en el precio medio de venta.
# 3. Recuperación parcial en 2023 y 2024:
# 	- A partir del segundo trimestre de 2023, se observa una ligera recuperación en los precios, con fluctuaciones a lo largo del año.
# 	- Para el 2024, los precios muestran un crecimiento significativo hasta el tercer trimestre, alcanzando valores cercanos a 1.45, aunque con una leve caída al final del año.
#
# Resumen:
# - El precio medio de venta muestra un aumento considerable entre 2021 y 2022, seguido de una fuerte caída en 2023.
# - En 2024, se presenta una recuperación gradual, pero sin alcanzar los niveles máximos observados en 2022.
# - Esta evolución sugiere una volatilidad en los precios con períodos de crecimiento y contracción, posiblemente influenciados por factores económicos o de oferta y demanda.

# %%
# Filtrar los datos para el año 2022
month_mean_california_organic_2022 = month_mean_california_organic[month_mean_california_organic.index.year == 2022]
month_mean_california_conventional_2022 = month_mean_california_conventional[month_mean_california_conventional.index.year == 2022]

# Crear una figura y un eje para la gráfica
fig, ax = plt.subplots(figsize=(12, 8))

# Graficar los datos de orgánico
ax.plot(month_mean_california_organic_2022.index.to_timestamp(), month_mean_california_organic_2022['ASP Current Year'], marker='o', label='Orgánico', color='g')
# Graficar los datos de convencional
ax.plot(month_mean_california_conventional_2022.index.to_timestamp(), month_mean_california_conventional_2022['ASP Current Year'], marker='o', label='Convencional', color='#800000')

# Etiqueta del eje x
ax.set_xlabel('Mes')
# Etiqueta del eje y
ax.set_ylabel('Media del precio medio de venta año en curso')
ax.tick_params(axis='y')

# Configurar el eje x para mostrar cada mes
ax.set_xticks(month_mean_california_organic_2022.index.to_timestamp())
ax.set_xticklabels(month_mean_california_organic_2022.index.strftime('%b'), rotation=45)

# Título de la gráfica
plt.title('Media del precio medio de venta año en curso por Mes en California (2022)')
plt.legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# La gráfica muestra la media del precio medio de venta por mes en California durante el año 2022, diferenciando entre aguacates orgánicos (línea verde) y convencionales (línea marrón). Las principales observaciones son:
#
# Aguacates orgánicos:
# 1. Los precios comienzan en enero con un valor cercano a 1.80 y muestran una tendencia al alza hasta alcanzar su pico máximo en julio, con un valor superior a 2.15.
# 2.	A partir de agosto, los precios comienzan a disminuir progresivamente, cerrando el año en diciembre con un valor aproximado de 1.70.
# 3.	Los precios orgánicos se mantienen significativamente más altos que los convencionales durante todo el año.
#
# Aguacates convencionales:
# 1.	Los precios inician en enero en un nivel mucho más bajo, alrededor de 1.30, y muestran una tendencia ascendente hasta alcanzar un pico en junio con un valor de aproximadamente 1.65.
# 2.	A partir de julio, los precios comienzan a descender de forma constante, cerrando el año en diciembre con un valor cercano a 1.25.
#
# Comparación:
# - Los aguacates orgánicos tienen un precio medio superior en comparación con los aguacates convencionales durante todo el año.
# - La diferencia entre ambos tipos se mantiene constante, aunque se amplía ligeramente hacia la segunda mitad del año, especialmente cuando los precios convencionales caen más bruscamente.
# - El comportamiento de ambos tipos de aguacates es similar: un aumento en la primera mitad del año, seguido de una caída en la segunda mitad.
#
# Resumen:
#
# El mercado de aguacates en 2022 muestra que los aguacates orgánicos tienen un mayor precio medio y son más estables en comparación con los convencionales, los cuales tienen precios más bajos y muestran una mayor volatilidad hacia finales del año.

# %%
# Filtrar los datos para el año 2023
month_mean_california_organic_2023 = month_mean_california_organic[month_mean_california_organic.index.year == 2023]
month_mean_california_conventional_2023 = month_mean_california_conventional[month_mean_california_conventional.index.year == 2023]

# Crear una figura y un eje para la gráfica
fig, ax = plt.subplots(figsize=(12, 8))

# Graficar los datos de orgánico
ax.plot(month_mean_california_organic_2023.index.to_timestamp(), month_mean_california_organic_2023['ASP Current Year'], marker='o', label='Orgánico', color='g')
# Graficar los datos de convencional
ax.plot(month_mean_california_conventional_2023.index.to_timestamp(), month_mean_california_conventional_2023['ASP Current Year'], marker='o', label='Convencional', color='#800000')

# Etiqueta del eje x
ax.set_xlabel('Mes')
# Etiqueta del eje y
ax.set_ylabel('Media del precio medio de venta año en curso')
ax.tick_params(axis='y')

# Configurar el eje x para mostrar cada mes
ax.set_xticks(month_mean_california_organic_2023.index.to_timestamp())
ax.set_xticklabels(month_mean_california_organic_2023.index.strftime('%b'), rotation=45)

# Título de la gráfica
plt.title('Media del precio medio de venta año en curso por Mes en California (2023)')
plt.legend()
fig.tight_layout()

plt.show()

# %% [markdown]
# La gráfica muestra la media del precio medio de venta por mes en California durante el 2023, diferenciando entre aguacates orgánicos (línea verde) y convencionales (línea marrón). Las observaciones clave son las siguientes:
#
# Aguacates orgánicos:
# 1. Los precios comienzan en enero con un valor de aproximadamente 1.50 y muestran un ligero aumento hasta febrero.
# 2.	En marzo y abril, los precios se mantienen estables, alrededor de 1.51, antes de comenzar a subir gradualmente entre mayo y septiembre.
# 3.	El precio alcanza su pico máximo en noviembre con un valor cercano a 1.75, seguido de una ligera caída en diciembre a 1.70.
# 4.	Los precios de los orgánicos se mantienen consistentes y superiores a lo largo del año en comparación con los convencionales.
#
# Aguacates convencionales:
# 1.	Los precios inician en enero con un valor cercano a 1.18 y muestran una ligera caída en febrero y marzo, alcanzando un mínimo alrededor de 1.12.
# 2.	A partir de abril, los precios muestran un aumento moderado, alcanzando su pico en julio con un valor de 1.32.
# 3.	Posteriormente, los precios comienzan a descender de manera constante, cerrando el año en diciembre con su valor más bajo, alrededor de 1.08.
#
# Comparación entre Orgánico y Convencional:
# - Los precios de los aguacates orgánicos son consistentemente más altos que los de los aguacates convencionales en todos los meses del año.
# - La diferencia entre ambos tipos se amplía especialmente hacia finales de año, cuando los precios convencionales caen mientras los orgánicos se mantienen estables.
# - Los aguacates convencionales muestran una mayor volatilidad y terminan con una tendencia a la baja, mientras que los orgánicos presentan un comportamiento más estable y una tendencia de crecimiento moderado.
#
# Resumen:
#
# El mercado de aguacates en 2023 refleja que los aguacates orgánicos mantienen un precio medio superior y más estable, mientras que los convencionales tienen precios más bajos y volátiles, con un descenso notable hacia finales del año.

# %%
# Filtrar los datos para el año 2024
month_mean_california_organic_2024 = month_mean_california_organic[month_mean_california_organic.index.year == 2024]
month_mean_california_conventional_2024 = month_mean_california_conventional[month_mean_california_conventional.index.year == 2024]

# Crear una figura y un eje para la gráfica
fig, ax = plt.subplots(figsize=(12, 8))

# Graficar los datos de orgánico
ax.plot(month_mean_california_organic_2024.index.to_timestamp(), month_mean_california_organic_2024['ASP Current Year'], marker='o', label='Orgánico', color='g')
# Graficar los datos de convencional
ax.plot(month_mean_california_conventional_2024.index.to_timestamp(), month_mean_california_conventional_2024['ASP Current Year'], marker='o', label='Convencional', color='#800000')

# Etiqueta del eje x
ax.set_xlabel('Mes')
# Etiqueta del eje y
ax.set_ylabel('Media del precio medio de venta año en curso')
ax.tick_params(axis='y')

# Configurar el eje x para mostrar cada mes
ax.set_xticks(month_mean_california_organic_2024.index.to_timestamp())
ax.set_xticklabels(month_mean_california_organic_2024.index.strftime('%b'), rotation=45)

# Título de la gráfica
plt.title('Media del precio medio de venta año en curso por Mes en California (2024)')
# Añadir la leyenda
plt.legend()
# Ajustar el diseño de la figura
fig.tight_layout()
# Mostrar la gráfica
plt.show()

# %% [markdown]
# La gráfica muestra la media del precio medio de venta por mes en California durante el 2024, diferenciando entre aguacates orgánicos (línea verde) y convencionales (línea marrón). Las principales observaciones son:
#
# Aguacates orgánicos:
# 1.	Los precios comienzan en enero alrededor de 1.70 y se mantienen relativamente estables hasta marzo.
# 2.	A partir de abril, se observa una tendencia ascendente constante, alcanzando un pico en octubre, con un valor de 2.00.
# 3.	Los precios permanecen en su nivel máximo durante noviembre y diciembre, estabilizándose en 2.00.
#
# Aguacates convencionales:
# 1.	Los precios inician en enero con un valor cercano a 1.15, seguido de una ligera caída en febrero.
# 2.	A partir de marzo, los precios muestran un aumento gradual hasta agosto, donde alcanzan su máximo del año, con un valor de 1.35.
# 3.	En los últimos meses del año (de septiembre a diciembre), los precios se estabilizan en torno a 1.32-1.33, mostrando poca variación.
#
# Comparación entre Orgánico y Convencional:
# - Los precios de los aguacates orgánicos son consistentemente más altos que los de los convencionales durante todo el año.
# - Mientras que los precios orgánicos muestran un incremento constante y una estabilización en niveles altos hacia finales de año, los precios convencionales permanecen más bajos y estables, con aumentos moderados.
# - La diferencia de precio entre orgánicos y convencionales es más marcada en la segunda mitad del año, donde los orgánicos superan los 2.00, mientras que los convencionales apenas llegan a 1.33.
#
# Resumen:
#
# En 2024, los aguacates orgánicos mantienen un precio superior y en crecimiento constante, alcanzando un valor máximo de 2.00 a finales del año. En contraste, los aguacates convencionales muestran precios más bajos y estables, con un comportamiento menos volátil. Esto refleja una demanda constante y mayor disposición a pagar por productos orgánicos en comparación con los convencionales.

# %% [markdown]
# **Análisis de Elasticidad de la demananda considerando los Días Festivos del Año**
#
# El siguiente análisis toma en cuenta los principales **días festivos** que ocurren a lo largo del año en el período 2021-2024, con el fin de evaluar la elasticidad de la demanda en relación con estos eventos clave.
#
# | **Festivo**              | **Fecha**                                     | **2021**       | **2022**       | **2023**       | **2024**       |
# |--------------------------|----------------------------------------------|----------------|----------------|----------------|----------------|
# | **Super Bowl**         | Varía (Generalmente el primer domingo de febrero) | 07/02/2021     | 13/02/2022     | 12/02/2023     | 11/02/2024     |
# | **Día de San Valentín**  | 14 de febrero                                |                |                |                |                |
# | **Día de San Patricio**  | 17 de marzo                                  |                |                |                |                |
# | **Pascua**               | Varía (Entre el 22 de marzo y el 25 de abril - domingo) | 04/04/2021     | 17/04/2022     | 09/04/2023     | 31/03/2024     |
# | **Cinco de Mayo**        | 5 de mayo                                    |                |                |                |                |
# | **Día de los Caídos**    | Último lunes de mayo                         | 31/05/2021     | 30/05/2022     | 29/05/2023     | 27/05/2024     |
# | **Día del Padre**        | Tercer domingo de junio                      | 20/06/2021     | 19/06/2022     | 18/06/2023     | 16/06/2024     |
# | **Día de la Independencia** | 4 de julio                                 |                |                |                |                |
# | **Día del Trabajo**      | Primer lunes de septiembre                   | 06/09/2021     | 05/09/2022     | 04/09/2023     | 02/09/2024     |
# | **Halloween**            | 31 de octubre                                |                |                |                |                |
# | **Día de Acción de Gracias** | Cuarto jueves de noviembre               | 25/11/2021     | 24/11/2022     | 23/11/2023     | 28/11/2024     |
# | **Navidad**              | 25 de diciembre                              |                |                |                |                |
# | **Nochevieja**           | 31 de diciembre                              |                |                |                |                |
#
# ---
#
# Este análisis permite identificar los posibles efectos estacionales en la elasticidad de la demanda, correlacionando los días festivos con las variaciones en el comportamiento de los consumidores.

# %%
# Filtrar los datos para incluir solo las columnas 'Current Year Week Ending' y 'Elasticity' para aguacates orgánicos
weekly_elasticity_california_organic = california_organic_df[['Current Year Week Ending', 'Elasticity']]
# Filtrar los datos para incluir solo las columnas 'Current Year Week Ending' y 'Elasticity' para aguacates convencionales
weekly_elasticity_california_conventional = california_conventional_df[['Current Year Week Ending', 'Elasticity']]

# Filtrar los datos de elasticidad semanal para aguacates orgánicos en el año 2021
weekly_elasticity_california_organic_2021 = weekly_elasticity_california_organic[weekly_elasticity_california_organic['Current Year Week Ending'].dt.year == 2021]
# Filtrar los datos de elasticidad semanal para aguacates convencionales en el año 2021
weekly_elasticity_california_conventional_2021 = weekly_elasticity_california_conventional[weekly_elasticity_california_conventional['Current Year Week Ending'].dt.year == 2021]

# Definir las fechas destacadas para el año 2021
highlight_dates_2021 = ['2021-02-07', '2021-02-14', '2021-03-17', '2021-04-04', '2021-05-05', '2021-05-31', '2021-06-20', '2021-07-04', '2021-09-06', '2021-10-31', '2021-11-25', '2021-12-25', '2021-12-31']
# Definir las etiquetas para las fechas destacadas del año 2021
highlight_labels_2021 = ['Super Bowl', 'Día de San Valentín', 'Día de San Patricio', 'Pascua', 'Cinco de Mayo', 'Día de los Caídos', 'Día del Padre', 'Día de la Independencia', 'Día del Trabajo', 'Halloween', 'Día de Acción de Gracias', 'Navidad', 'Nochevieja']



# Crear una figura de tamaño 10x6 para la gráfica
plt.figure(figsize=(12, 8))
# Graficar la elasticidad de la demanda para aguacates orgánicos en 2021
ax = weekly_elasticity_california_organic_2021.set_index('Current Year Week Ending')['Elasticity'].plot(kind='line', marker='o', label='Orgánico', color='g')
# Graficar la elasticidad de la demanda para aguacates convencionales en 2021 en el mismo eje
weekly_elasticity_california_conventional_2021.set_index('Current Year Week Ending')['Elasticity'].plot(kind='line', marker='o', label='Convencional', ax=ax, color='#800000')
# Etiqueta del eje x
plt.xlabel('Semana')
# Etiqueta del eje y
plt.ylabel('Elasticidad de la demanda respecto al precio')
# Título de la gráfica
plt.title('Elasticidad de la demanda respecto al precio por semana para aguacates en California (2021)')
# Añadir la leyenda
plt.legend()
# Añadir una cuadrícula
plt.grid(True)

# Convertir las fechas destacadas a formato datetime
highlight_dates_dt = pd.to_datetime(highlight_dates_2021)
# Configurar las marcas personalizadas en el eje x
ax.set_xticks(highlight_dates_dt)
# Configurar las etiquetas personalizadas en el eje x
ax.set_xticklabels(highlight_labels_2021, rotation=90)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# El gráfico muestra la elasticidad de la demanda respecto al precio de aguacates orgánicos y convencionales en California durante el 2021, considerando fechas festivas.
# - Los aguacates orgánicos presentan mayor volatilidad, destacando una caída extrema en Cinco de Mayo y fluctuaciones en fechas como Día del Trabajo.
# - Los aguacates convencionales tienen una demanda más estable, excepto un pico significativo en Nochevieja, indicando alta sensibilidad al precio en esta fecha.
#
# En resumen, las festividades afectan más la elasticidad de los orgánicos, mientras que los convencionales son más estables con excepciones puntuales.

# %%
# Filtrar los datos de elasticidad semanal para aguacates orgánicos en el año 2022
weekly_elasticity_california_organic_2022 = weekly_elasticity_california_organic[weekly_elasticity_california_organic['Current Year Week Ending'].dt.year == 2022]

# Filtrar los datos de elasticidad semanal para aguacates convencionales en el año 2022
weekly_elasticity_california_conventional_2022 = weekly_elasticity_california_conventional[weekly_elasticity_california_conventional['Current Year Week Ending'].dt.year == 2022]

# Definir las fechas destacadas para el año 2022
highlight_dates_2022 = ['2022-02-14', '2022-03-17', '2022-04-17', '2022-05-05', '2022-05-30', '2022-06-19', '2022-07-04', '2022-09-05', '2022-10-31', '2022-11-24', '2022-12-25', '2022-12-31']

# Definir las etiquetas para las fechas destacadas del año 2022
highlight_labels_2022 = ['Super Bowl (02-13) y \nDía de San Valentín (02-14)', 'Día de San Patricio', 'Pascua', 'Cinco de Mayo', 'Día de los Caídos', 'Día del Padre', 'Día de la Independencia', 'Día del Trabajo', 'Halloween', 'Día de Acción de Gracias', 'Navidad', 'Nochevieja']

# Crear una figura de tamaño 10x6 para la gráfica
plt.figure(figsize=(12, 8))

# Graficar la elasticidad de la demanda para aguacates orgánicos en 2022
ax = weekly_elasticity_california_organic_2022.set_index('Current Year Week Ending')['Elasticity'].plot(kind='line', marker='o', label='Orgánico', color='g')

# Graficar la elasticidad de la demanda para aguacates convencionales en 2022 en el mismo eje
weekly_elasticity_california_conventional_2022.set_index('Current Year Week Ending')['Elasticity'].plot(kind='line', marker='o', label='Convencional', ax=ax, color='#800000')

# Etiqueta del eje x
plt.xlabel('Semana')

# Etiqueta del eje y
plt.ylabel('Elasticidad de la demanda respecto al precio')

# Título de la gráfica
plt.title('Elasticidad de la demanda respecto al precio por semana para aguacates en California (2022)')

# Añadir la leyenda
plt.legend()

# Añadir una cuadrícula
plt.grid(True)

# Convertir las fechas destacadas a formato datetime
highlight_dates_dt = pd.to_datetime(highlight_dates_2022)

# Configurar las marcas personalizadas en el eje x
ax.set_xticks(highlight_dates_dt)

# Configurar las etiquetas personalizadas en el eje x
ax.set_xticklabels(highlight_labels_2022, rotation=90)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# La gráfica muestra la elasticidad de la demanda respecto al precio de aguacates orgánicos (línea verde) y convencionales (línea marrón) por semana en California durante el 2022, considerando las fechas festivas.
#
# Observaciones clave:
# - Los aguacates convencionales presentan picos extremos negativos alrededor de Pascua y fluctuaciones menores en otras fechas, lo que sugiere una alta sensibilidad de la demanda en esa semana.
# - Los aguacates orgánicos muestran un comportamiento más estable, con una ligera elasticidad positiva en ciertas semanas como Cinco de Mayo.
# - Las variaciones son más pronunciadas para los aguacates convencionales, reflejando una demanda más volátil frente a cambios en el precio en comparación con los orgánicos.
#
# En resumen, la elasticidad de los convencionales es más sensible y volátil en fechas clave como Pascua, mientras que los orgánicos mantienen una elasticidad más controlada.

# %%
# Filtrar los datos de elasticidad semanal para aguacates orgánicos en el año 2023
weekly_elasticity_california_organic_2023 = weekly_elasticity_california_organic[weekly_elasticity_california_organic['Current Year Week Ending'].dt.year == 2023]

# Filtrar los datos de elasticidad semanal para aguacates convencionales en el año 2023
weekly_elasticity_california_conventional_2023 = weekly_elasticity_california_conventional[weekly_elasticity_california_conventional['Current Year Week Ending'].dt.year == 2023]

# Definir las fechas destacadas para el año 2023
highlight_dates_2023 = ['2023-02-14', '2023-03-17', '2023-04-09', '2023-05-05', '2023-05-29', '2023-06-18', '2023-07-04', '2023-09-04', '2023-10-31', '2023-11-23', '2023-12-25', '2023-12-31']

# Definir las etiquetas para las fechas destacadas del año 2023
highlight_labels_2023 = ['SuperBowl (02-12) y \nDía de San Valentín (02-14)', 'Día de San Patricio', 'Pascua', 'Cinco de Mayo', 'Día de los Caídos', 'Día del Padre', 'Día de la Independencia', 'Día del Trabajo', 'Halloween', 'Día de Acción de Gracias', 'Navidad', 'Nochevieja']

# Crear una figura de tamaño 12x8 para la gráfica
plt.figure(figsize=(12, 8))

# Graficar la elasticidad de la demanda para aguacates orgánicos en 2023
ax = weekly_elasticity_california_organic_2023.set_index('Current Year Week Ending')['Elasticity'].plot(kind='line', marker='o', label='Orgánico', color='g')

# Graficar la elasticidad de la demanda para aguacates convencionales en 2023 en el mismo eje
weekly_elasticity_california_conventional_2023.set_index('Current Year Week Ending')['Elasticity'].plot(kind='line', marker='o', label='Convencional', ax=ax, color='#800000')

# Etiqueta del eje x
plt.xlabel('Semana')

# Etiqueta del eje y
plt.ylabel('Elasticidad de la demanda respecto al precio')

# Título de la gráfica
plt.title('Elasticidad de la demanda respecto al precio por semana para aguacates en California (2023)')

# Añadir la leyenda
plt.legend()

# Añadir una cuadrícula
plt.grid(True)

# Convertir las fechas destacadas a formato datetime
highlight_dates_dt = pd.to_datetime(highlight_dates_2023)

# Configurar las marcas personalizadas en el eje x
ax.set_xticks(highlight_dates_dt)

# Configurar las etiquetas personalizadas en el eje x
ax.set_xticklabels(highlight_labels_2023, rotation=90)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# La gráfica muestra la elasticidad de la demanda respecto al precio para aguacates (tanto orgánicos como convencionales) en California durante 2023, representada por semanas.
#
# Observaciones clave:
# 1. Picos de Elasticidad:
#     - Se observan grandes picos positivos en la elasticidad durante ciertas semanas (por ejemplo, Día de la Independencia y Acción de Gracias), especialmente en los aguacates orgánicos. Esto indica una alta sensibilidad a cambios en los precios durante festivos o eventos especiales.
#     - Los aguacates convencionales también muestran picos, pero son más pequeños y menos frecuentes en comparación con los orgánicos.
# 2. Elasticidad Negativa:
#     - Existen períodos de elasticidad negativa, principalmente para los aguacates orgánicos (por ejemplo, cerca del Cinco de Mayo y Acción de Gracias), lo que sugiere que la demanda disminuyó a pesar de que los precios bajaron.
# 3. Tendencia General:
#     - Los aguacates orgánicos muestran una mayor volatilidad en su elasticidad a lo largo del año, lo que refleja una mayor sensibilidad de los consumidores a los cambios de precio.
#     - Los aguacates convencionales muestran una elasticidad más estable, con variaciones menores durante las semanas.
#
# Interpretación:
#
# La demanda de aguacates orgánicos es más elástica, especialmente durante festivos y eventos importantes, lo que sugiere que los consumidores son más sensibles a los cambios de precio en esos períodos. En contraste, los aguacates convencionales tienen una demanda más estable y menos afectada por las fluctuaciones de precio.

# %%
# Filtrar los datos para la elasticidad semanal de aguacates orgánicos en 2024
weekly_elasticity_california_organic_2024 = weekly_elasticity_california_organic[weekly_elasticity_california_organic['Current Year Week Ending'].dt.year == 2024]

# Filtrar los datos para la elasticidad semanal de aguacates convencionales en 2024
weekly_elasticity_california_conventional_2024 = weekly_elasticity_california_conventional[weekly_elasticity_california_conventional['Current Year Week Ending'].dt.year == 2024]

# Definir las fechas destacadas para el año 2024
highlight_dates_2024 = ['2024-02-14', '2024-03-17', '2024-03-31', '2024-05-05', '2024-05-27', '2024-06-16', '2024-07-04', '2024-09-02', '2024-10-31', '2024-11-28', '2024-12-25', '2024-12-31']

# Definir las etiquetas para las fechas destacadas en 2024
highlight_labels_2024 = ['Super Bowl (02-11) y \nDía de San Valentín (02-14)', 'Día de San Patricio', 'Pascua', 'Cinco de Mayo', 'Día de los Caídos', 'Día del Padre', 'Día de la Independencia', 'Día del Trabajo', 'Halloween', 'Día de Acción de Gracias', 'Navidad', 'Nochevieja']

# Crear una figura con un tamaño de 10x6 pulgadas
plt.figure(figsize=(12, 8))

# Graficar la elasticidad semanal de aguacates orgánicos en 2024
ax = weekly_elasticity_california_organic_2024.set_index('Current Year Week Ending')['Elasticity'].plot(kind='line', marker='o', label='Orgánico', color='g')

# Graficar la elasticidad semanal de aguacates convencionales en 2024 en el mismo eje
weekly_elasticity_california_conventional_2024.set_index('Current Year Week Ending')['Elasticity'].plot(kind='line', marker='o', label='Convencional', ax=ax, color='#800000')

# Establecer la etiqueta para el eje x
plt.xlabel('Semana')

# Establecer la etiqueta para el eje y
plt.ylabel('Elasticidad de la demanda respecto al precio')

# Establecer el título de la gráfica
plt.title('Elasticidad de la demanda respecto al precio por semana para aguacates en California (2024)')

# Añadir una leyenda a la gráfica
plt.legend()

# Añadir una cuadrícula a la gráfica
plt.grid(True)

# Convertir las fechas destacadas a formato datetime
highlight_dates_dt = pd.to_datetime(highlight_dates_2024)

# Establecer marcas personalizadas en el eje x usando las fechas destacadas
ax.set_xticks(highlight_dates_dt)

# Establecer etiquetas personalizadas en el eje x usando las etiquetas destacadas, rotadas 90 grados
ax.set_xticklabels(highlight_labels_2024, rotation=90)

# Mostrar la gráfica
plt.show()
