# %%
import pandas as pd

# Load the avocado dataset
#file_path = '../dataset/Avocado_HassAvocadoBoard_20152023v1.0.1.csv'

file_path = ['../dataset/2021-plu-total-hab-data.csv',
              '../dataset/2022-plu-total-hab-data.csv',
              '../dataset/2023-plu-total-hab-data.csv',
              '../dataset/2024-plu-total-hab-data.csv']

merged_df = pd.concat([pd.read_csv(file) for file in file_path])

merged_df.to_csv('../dataset/merged_df.csv', index=False)

#avocado_df = pd.read_csv(file_path)

# %%
#merged_df['Date'] = pd.to_datetime(merged_df['Date'])

#df = merged_df[merged_df['Date'] > '2022-01-02']

#df.to_csv('../dataset/avocado_2022-2023.csv', index=False)

# %%
print(merged_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23596 entries, 0 to 5184
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Geography                  23596 non-null  object
#  1   Timeframe                  23592 non-null  object
#  2   Current Year Week Ending   23592 non-null  object
#  3   Type                       23592 non-null  object
#  4   ASP Current Year           23592 non-null  float64
#  5   Total Bulk and Bags Units  23592 non-null  float64
#  6   4046 Units                 23592 non-null  float64
#  7   4225 Units                 23592 non-null  float64
#  8   4770 Units                 23592 non-null  float64
#  9   TotalBagged Units          23592 non-null  float64
#  10  SmlBagged Units            0 non-null      float64
#  11  LrgBagged Units            0 non-null      float64
#  12  X-LrgBagged Units          0 non-null      float64
# ...

# %%
merged_df.describe()
# Out:
#        ASP Current Year  Total Bulk and Bags Units    4046 Units  \
# count      23592.000000               2.359200e+04  2.359200e+04
# mean           1.336364               1.018042e+06  4.645233e+05
# std            0.333637               4.063484e+06  1.960515e+06
# min            0.607247               2.676100e+03  0.000000e+00
# 25%            1.082494               2.982693e+04  1.110342e+03
# 50%            1.295170               1.631951e+05  4.425304e+04
# 75%            1.535885               5.354342e+05  2.327404e+05
# max            3.179988               6.034646e+07  3.113597e+07
#
#          4225 Units    4770 Units  TotalBagged Units  SmlBagged Units  \
# count  2.359200e+04  2.359200e+04       2.359200e+04              0.0
# mean   2.140635e+05  2.880445e+04       3.106510e+05              NaN
# std    9.115871e+05  1.443652e+05       1.146035e+06              NaN
# min    0.000000e+00  0.000000e+00       1.251590e+03              NaN
# ...

# %%
merged_df.count()
# Out:
# Geography                    23596
# Timeframe                    23592
# Current Year Week Ending     23592
# Type                         23592
# ASP Current Year             23592
# Total Bulk and Bags Units    23592
# 4046 Units                   23592
# 4225 Units                   23592
# 4770 Units                   23592
# TotalBagged Units            23592
# SmlBagged Units                  0
# LrgBagged Units                  0
# X-LrgBagged Units                0
# dtype: int64

# %%
unique_values = merged_df.nunique()
unique_values
# Out:
# Geography                       60
# Timeframe                        1
# Current Year Week Ending       200
# Type                             2
# ASP Current Year             23586
# Total Bulk and Bags Units    23579
# 4046 Units                   23348
# 4225 Units                   23160
# 4770 Units                   13313
# TotalBagged Units            23571
# SmlBagged Units                  0
# LrgBagged Units                  0
# X-LrgBagged Units                0
# dtype: int64

# %%
print(merged_df['Geography'].unique())
# Out:
# ['Albany' 'Atlanta' 'Baltimore/Washington' 'Birmingham/Montgomery' 'Boise'
#  'Boston' 'Buffalo/Rochester' 'Charlotte' 'Chicago' 'Cincinnati/Dayton'
#  'Columbus' 'Dallas/Ft. Worth' 'Denver' 'Detroit' 'Grand Rapids'
#  'Harrisburg/Scranton' 'Hartford/Springfield' 'Houston' 'Indianapolis'
#  'Jacksonville' 'Las Vegas' 'Los Angeles' 'Louisville'
#  'Miami/Ft. Lauderdale' 'Nashville' 'Northern New England'
#  'New Orleans/Mobile' 'New York' 'Orlando' 'Peoria/Springfield'
#  'Philadelphia' 'Phoenix/Tucson' 'Pittsburgh' 'Portland' 'Providence'
#  'Raleigh/Greensboro' 'Richmond/Norfolk' 'Roanoke' 'Sacramento'
#  'San Diego' 'San Francisco' 'Seattle' 'South Carolina' 'Spokane'
#  'St. Louis' 'Syracuse' 'Tampa' 'Toledo' 'West Tex/New Mexico' 'Wichita'
#  'California' 'Great Lakes' 'Midsouth' 'Northeast' 'Plains'
#  'South Central' 'Southeast' 'West' 'Total U.S.'
# ...

# %%
merged_df.head()
# Out:
#                Geography Timeframe Current Year Week Ending          Type  \
# 0                 Albany    Weekly      2021-01-11 00:00:00  Conventional
# 1                Atlanta    Weekly      2021-01-11 00:00:00  Conventional
# 2   Baltimore/Washington    Weekly      2021-01-11 00:00:00  Conventional
# 3  Birmingham/Montgomery    Weekly      2021-01-11 00:00:00  Conventional
# 4                  Boise    Weekly      2021-01-11 00:00:00  Conventional
#
#    ASP Current Year  Total Bulk and Bags Units  4046 Units  4225 Units  \
# 0          1.194755                  150112.17    17074.48   100955.99
# 1          0.812573                  892386.79   542057.87   146831.96
# 2          1.073194                 1203423.07   402341.66   365970.12
# 3          0.757310                  402306.65   263020.12    17855.75
# 4          1.033496                  138962.53    57581.95    34044.86
#
#    4770 Units  TotalBagged Units  SmlBagged Units  LrgBagged Units  \
# ...

# %%
cities = ['Albany', 'Atlanta', 'Boise', 'Boston', 'Charlotte', 'Chicago', 'Columbus', 
          'Denver', 'Detroit', 'Grand Rapids', 'Houston', 'Indianapolis', 'Jacksonville', 
          'Las Vegas', 'Los Angeles', 'Louisville', 'Nashville', 'New York', 'Orlando', 
          'Philadelphia', 'Pittsburgh', 'Providence', 'Portland', 'Roanoke', 'Sacramento', 
          'San Diego', 'San Francisco', 'Seattle', 'Spokane', 'St. Louis', 'Syracuse', 
          'Tampa', 'Toledo', 'Wichita']

regions = ['Baltimore/Washington', 'Birmingham/Montgomery', 'Buffalo/Rochester', 
           'Cincinnati/Dayton', 'Dallas/Ft. Worth', 'Harrisburg/Scranton', 
           'Hartford/Springfield', 'Miami/Ft. Lauderdale', 'New Orleans/Mobile', 
           'Northern New England', 'Peoria/Springfield', 'Phoenix/Tucson', 
           'Raleigh/Greensboro', 'Richmond/Norfolk', 'South Carolina', 'West Tex/New Mexico']

greaterregions = ['California', 'Great Lakes', 'Midsouth', 'Northeast', 'Plains', 
                  'South Central', 'Southeast', 'West']

# %%
filtered_df_regions = merged_df[merged_df['Geography'].isin(regions)]

filtered_df_regions.head()
# Out:
#                 Geography Timeframe Current Year Week Ending          Type  \
# 2    Baltimore/Washington    Weekly      2021-01-11 00:00:00  Conventional
# 3   Birmingham/Montgomery    Weekly      2021-01-11 00:00:00  Conventional
# 6       Buffalo/Rochester    Weekly      2021-01-11 00:00:00  Conventional
# 9       Cincinnati/Dayton    Weekly      2021-01-11 00:00:00  Conventional
# 11       Dallas/Ft. Worth    Weekly      2021-01-11 00:00:00  Conventional
#
#     ASP Current Year  Total Bulk and Bags Units  4046 Units  4225 Units  \
# 2           1.073194                 1203423.07   402341.66   365970.12
# 3           0.757310                  402306.65   263020.12    17855.75
# 6           0.952804                  268850.26    61042.64    65974.10
# 9           0.889852                  347087.91   141141.39   160509.52
# 11          0.618348                 1900546.17   806118.35   388064.58
#
#     4770 Units  TotalBagged Units  SmlBagged Units  LrgBagged Units  \
# ...

# %%
file_paths = ['../dataset/Volume Hass Avocado Board Suppliers 2022.csv',
              '../dataset/Volume Hass Avocado Board Suppliers 2023.csv',
              '../dataset/Volume Hass Avocado Board Suppliers 2024.csv',
              '../dataset/Volume Hass Avocado Board Suppliers 2025 (projection).csv']

suppliers_df = pd.concat([pd.read_csv(file) for file in file_paths])

suppliers_df.to_csv('../dataset/merged_suppliers.csv', index=False)

print(suppliers_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 208 entries, 0 to 51
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Week Ending         208 non-null    object
#  1   Year                208 non-null    int64
#  2   Status              208 non-null    object
#  3   Total Volume        208 non-null    object
#  4   California          208 non-null    object
#  5   Chile               208 non-null    object
#  6   Mexico              182 non-null    object
#  7   Peru                208 non-null    object
#  8   Colombia            208 non-null    object
#  9   Dominican Republic  156 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 17.9+ KB
# None

# %%
#Univardiado

# %%
# Agrupar por trimestres usando Grouper
merged_df['Current Year Week Ending'] = pd.to_datetime(merged_df['Current Year Week Ending'], errors='coerce')

# Agrupar por trimestres con Grouper
grouped = merged_df.groupby(pd.Grouper(key='Current Year Week Ending', freq='Q'))

# Mostrar los grupos
for period, group in grouped:
    print(f"Trimestre que termina en {period}:")
    print(group)
# Out:
# Trimestre que termina en 2021-03-31 00:00:00:
#                   Geography Timeframe Current Year Week Ending          Type  \
# 0                    Albany    Weekly               2021-01-11  Conventional
# 1                   Atlanta    Weekly               2021-01-11  Conventional
# 2      Baltimore/Washington    Weekly               2021-01-11  Conventional
# 3     Birmingham/Montgomery    Weekly               2021-01-11  Conventional
# 4                     Boise    Weekly               2021-01-11  Conventional
# ...                     ...       ...                      ...           ...
# 1411                 Plains    Weekly               2021-03-28       Organic
# 1412          South Central    Weekly               2021-03-28       Organic
# 1413              Southeast    Weekly               2021-03-28       Organic
# 1414                   West    Weekly               2021-03-28       Organic
# 1415             Total U.S.    Weekly               2021-03-28       Organic
# ...

# %%
# Filtrar por el tercer trimestre (Q3)
# Ejemplo: Q3 del año 2021
q3_data = merged_df[
    (merged_df['Current Year Week Ending'] >= '2021-07-01') &
    (merged_df['Current Year Week Ending'] <= '2021-09-30')
]

print(q3_data)
# Out:
#                   Geography Timeframe Current Year Week Ending          Type  \
# 2950                 Albany    Weekly               2021-07-04  Conventional
# 2951                Atlanta    Weekly               2021-07-04  Conventional
# 2952   Baltimore/Washington    Weekly               2021-07-04  Conventional
# 2953  Birmingham/Montgomery    Weekly               2021-07-04  Conventional
# 2954                  Boise    Weekly               2021-07-04  Conventional
# ...                     ...       ...                      ...           ...
# 4479                 Plains    Weekly               2021-09-26       Organic
# 4480          South Central    Weekly               2021-09-26       Organic
# 4481              Southeast    Weekly               2021-09-26       Organic
# 4482                   West    Weekly               2021-09-26       Organic
# 4483             Total U.S.    Weekly               2021-09-26       Organic
#
# ...

# %%
# Filtrar los datos para el tercer trimestre (Q3)
q3_data = merged_df[
    (merged_df['Current Year Week Ending'] >= '2021-07-01') &
    (merged_df['Current Year Week Ending'] <= '2021-09-30')
]

# Contar la distribución de la variable 'Type' dentro del Q3
q3_type_distribution = q3_data['Type'].value_counts()

q3_type_distribution
# Out:
# Conventional    767
# Organic         767
# Name: Type, dtype: int64

# %%
Bivariado

Trimestre vs Total Volumne (venta)
Regiones vs Total volumen (venta)
Trimestre vs AVG precio

# %%
import pandas as pd
import matplotlib.pyplot as plt

merged_df = pd.read_csv('../dataset/merged_df.csv')

cities = ['Albany', 'Atlanta', 'Boise', 'Boston', 'Charlotte', 'Chicago', 'Columbus', 
          'Denver', 'Detroit', 'Grand Rapids', 'Houston', 'Indianapolis', 'Jacksonville', 
          'Las Vegas', 'Los Angeles', 'Louisville', 'Nashville', 'New York', 'Orlando', 
          'Philadelphia', 'Pittsburgh', 'Providence', 'Portland', 'Roanoke', 'Sacramento', 
          'San Diego', 'San Francisco', 'Seattle', 'Spokane', 'St. Louis', 'Syracuse', 
          'Tampa', 'Toledo', 'Wichita']

regions = ['Baltimore/Washington', 'Birmingham/Montgomery', 'Buffalo/Rochester', 
           'Cincinnati/Dayton', 'Dallas/Ft. Worth', 'Harrisburg/Scranton', 
           'Hartford/Springfield', 'Miami/Ft. Lauderdale', 'New Orleans/Mobile', 
           'Northern New England', 'Peoria/Springfield', 'Phoenix/Tucson', 
           'Raleigh/Greensboro', 'Richmond/Norfolk', 'South Carolina', 'West Tex/New Mexico']

greaterregions = ['California', 'Great Lakes', 'Midsouth', 'Northeast', 'Plains', 
                  'South Central', 'Southeast', 'West']

filtered_df_regions = merged_df[merged_df['Geography'].isin(regions)]

# %%
filtered_df_regions.head()
# Out:
#                 Geography Timeframe Current Year Week Ending          Type  \
# 2    Baltimore/Washington    Weekly      2021-01-11 00:00:00  Conventional
# 3   Birmingham/Montgomery    Weekly      2021-01-11 00:00:00  Conventional
# 6       Buffalo/Rochester    Weekly      2021-01-11 00:00:00  Conventional
# 9       Cincinnati/Dayton    Weekly      2021-01-11 00:00:00  Conventional
# 11       Dallas/Ft. Worth    Weekly      2021-01-11 00:00:00  Conventional
#
#     ASP Current Year  Total Bulk and Bags Units  4046 Units  4225 Units  \
# 2           1.073194                 1203423.07   402341.66   365970.12
# 3           0.757310                  402306.65   263020.12    17855.75
# 6           0.952804                  268850.26    61042.64    65974.10
# 9           0.889852                  347087.91   141141.39   160509.52
# 11          0.618348                 1900546.17   806118.35   388064.58
#
#     4770 Units  TotalBagged Units  SmlBagged Units  LrgBagged Units  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

filtered_df_regions['Current Year Week Ending'] = pd.to_datetime(filtered_df_regions['Current Year Week Ending'])

filtered_df_regions['Quarter'] = filtered_df_regions['Current Year Week Ending'].dt.to_period('Q')
quarterly_mean = filtered_df_regions.groupby('Quarter')['Total Bulk and Bags Units'].mean()

plt.figure(figsize=(10, 6))
quarterly_mean.plot(kind='bar')
plt.xlabel('Trimestre')
plt.ylabel('Media del total de unidades a granel y en sacos (lb)')
plt.title('Media del total de unidades a granel y en sacos (lb) por Trimestre')
plt.show()
# Out:
# /var/folders/7z/00rgwf311yn2q_dbm8dwq25m0000gn/T/ipykernel_5179/2853776983.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_regions['Current Year Week Ending'] = pd.to_datetime(filtered_df_regions['Current Year Week Ending'])
# /var/folders/7z/00rgwf311yn2q_dbm8dwq25m0000gn/T/ipykernel_5179/2853776983.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_regions['Quarter'] = filtered_df_regions['Current Year Week Ending'].dt.to_period('Q')

# %%
import pandas as pd
import matplotlib.pyplot as plt

filtered_df_regions["Current Year Week Ending"] = pd.to_datetime(filtered_df_regions["Current Year Week Ending"])

# Extract the quarter from the 'Current Year Week Ending' column
filtered_df_regions['Quarter'] = filtered_df_regions['Current Year Week Ending'].dt.to_period('Q')

# Group by quarter and calculate the mean of 'Total Bulk and Bags Units'
quarterly_mean = filtered_df_regions.groupby('Quarter')['Total Bulk and Bags Units'].mean().reset_index()

quarterly_mean.head()
# Out:
# /var/folders/7z/00rgwf311yn2q_dbm8dwq25m0000gn/T/ipykernel_4998/4135265734.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_regions["Current Year Week Ending"] = pd.to_datetime(filtered_df_regions["Current Year Week Ending"])
# /var/folders/7z/00rgwf311yn2q_dbm8dwq25m0000gn/T/ipykernel_4998/4135265734.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_regions['Quarter'] = filtered_df_regions['Current Year Week Ending'].dt.to_period('Q')
# ...

# %%
# Plot the data
fig, ax1 = plt.subplots()

# Plot the 'Current Year Week Ending' by quarter
ax1.plot(filtered_df_regions['Current Year Week Ending'], filtered_df_regions['Quarter'], 'b-')
ax1.set_xlabel('Current Year Week Ending')
ax1.set_ylabel('Quarter', color='b')

# Create another y-axis for the mean of 'Total Bulk and Bags Units'
ax2 = ax1.twinx()
ax2.plot(quarterly_mean['Quarter'].astype(str), quarterly_mean['Total Bulk and Bags Units'], 'r-')
ax2.set_ylabel('Mean of Total Bulk and Bags Units', color='r')

plt.title('Current Year Week Ending by Quarter and Mean of Total Bulk and Bags Units')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       2 fig, ax1 = plt.subplots()
#       4 # Plot the 'Current Year Week Ending' by quarter
# ----> 5 ax1.plot(filtered_df_regions['Current Year Week Ending'], filtered_df_regions['Quarter'], 'b-')
#       6 ax1.set_xlabel('Current Year Week Ending')
#       7 ax1.set_ylabel('Quarter', color='b')
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_axes.py:1781, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
# -> 1781     self.add_line(line)
#    1782 if scalex:
#    1783     self._request_autoscale_view("x")
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_base.py:2339, in _AxesBase.add_line(self, line)
#    2336 if line.get_clip_path() is None:
# ...

# %%
# Group by quarter and calculate the average of "AveragePrice" and the sum of "Total Volume"
quarterly_data = filtered_df_regions.groupby(pd.Grouper(key="Current Year Week Ending", freq="QE")).agg({"Total Bulk and Bags Units": "mean", "Total Volume": "sum"}).reset_index()

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 6))

ax1.plot(quarterly_data["Date"], quarterly_data["AveragePrice"], marker="o", linestyle="-", color="b")
ax1.set_title("Average Price and Total Volume by Quarter")
ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax1.set_xticklabels([])  # Hide x-axis labels for the first subplot
#ax1.set_xlabel("Quarter")
ax1.set_ylabel("Average Price")

ax2.plot(quarterly_data["Date"], quarterly_data["Total Volume"], marker="o", linestyle="-", color="g")
#ax2.set_title("Total Volume by Quarter")
ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax2.set_xlabel("Quarter")
ax2.set_ylabel("Total Volume")

plt.tight_layout()
plt.show()
